# %% [markdown]
# ## Manipulating data with pandas

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("new_car_sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales['Make'].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales['Make'].str.capitalize()
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       Bmw
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# re assign the column value and save it.
car_sales['Make'] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_miss = pd.read_csv("car-sales-missing.csv")

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    Red        87899.0      4   $5,000.00
# 2  Toyota   Blue        32549.0      3         NaN
# 3     BMW  Black        11179.0      5  $22,000.00
# 4  Nissan  White            NaN      4   $3,500.00
# 5  Toyota  Green        99213.0      4         NaN
# 6   Honda    NaN            NaN      4   $7,500.00
# 7   Honda    NaN            NaN      4         NaN
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
car_sales_miss['Colour'].fillna('Black')
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6    Black
# 7    Black
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    Red        87899.0      4   $5,000.00
# 2  Toyota   Blue        32549.0      3         NaN
# 3     BMW  Black        11179.0      5  $22,000.00
# 4  Nissan  White            NaN      4   $3,500.00
# 5  Toyota  Green        99213.0      4         NaN
# 6   Honda    NaN            NaN      4   $7,500.00
# 7   Honda    NaN            NaN      4         NaN
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
car_sales_miss['Colour'] = car_sales_miss['Colour'].fillna('Black')

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    Red        87899.0      4   $5,000.00
# 2  Toyota   Blue        32549.0      3         NaN
# 3     BMW  Black        11179.0      5  $22,000.00
# 4  Nissan  White            NaN      4   $3,500.00
# 5  Toyota  Green        99213.0      4         NaN
# 6   Honda  Black            NaN      4   $7,500.00
# 7   Honda  Black            NaN      4         NaN
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
car_sales_miss['Odometer (KM)'].fillna(car_sales_miss['Odometer (KM)'].mean(), inplace=True)

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000      4   $4,000.00
# 1   Honda    Red   87899.000000      4   $5,000.00
# 2  Toyota   Blue   32549.000000      3         NaN
# 3     BMW  Black   11179.000000      5  $22,000.00
# 4  Nissan  White   67497.571429      4   $3,500.00
# 5  Toyota  Green   99213.000000      4         NaN
# 6   Honda  Black   67497.571429      4   $7,500.00
# 7   Honda  Black   67497.571429      4         NaN
# 8  Toyota  White   60000.000000      4   $6,250.00
# 9  Nissan  White   31600.000000      4   $9,700.00

# %%
# To remove the row with none value
car_sales_miss.dropna(inplace=True)

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000      4   $4,000.00
# 1   Honda    Red   87899.000000      4   $5,000.00
# 3     BMW  Black   11179.000000      5  $22,000.00
# 4  Nissan  White   67497.571429      4   $3,500.00
# 6   Honda  Black   67497.571429      4   $7,500.00
# 8  Toyota  White   60000.000000      4   $6,250.00
# 9  Nissan  White   31600.000000      4   $9,700.00

# %%
 #re open the file and export it as a seperate file
car_sales_miss = pd.read_csv("car-sales-missing.csv")

# %%
car_sales_miss
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    Red        87899.0      4   $5,000.00
# 2  Toyota   Blue        32549.0      3         NaN
# 3     BMW  Black        11179.0      5  $22,000.00
# 4  Nissan  White            NaN      4   $3,500.00
# 5  Toyota  Green        99213.0      4         NaN
# 6   Honda    NaN            NaN      4   $7,500.00
# 7   Honda    NaN            NaN      4         NaN
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
car_sales_miss_dropped = car_sales_miss.dropna()

# %%
car_sales_miss_dropped
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    Red        87899.0      4   $5,000.00
# 3     BMW  Black        11179.0      5  $22,000.00
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
car_sales_miss_dropped.to_csv("car-sales-missed-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
#Add column into the existing table

seat_numbers = pd.Series([3,5,6,7,8,9,4,5,6,2])
car_sales['Seats'] = seat_numbers

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00      3
# 1   honda    Red          87899      4   $5,000.00      5
# 2  toyota   Blue          32549      3   $7,000.00      6
# 3     bmw  Black          11179      5  $22,000.00      7
# 4  nissan  White         213095      4   $3,500.00      8
# 5  toyota  Green          99213      4   $4,500.00      9
# 6   honda   Blue          45698      4   $7,500.00      4
# 7   honda   Blue          54738      4   $7,000.00      5
# 8  toyota  White          60000      4   $6,250.00      6
# 9  nissan  White          31600      4   $9,700.00      2

# %%
fuel_used_per_km = pd.Series([7.5,4.5,2.3,5.4,6.7,7.8,9.5,4.4,6.7,8.9])
car_sales["fuel_used_per_km"] = fuel_used_per_km

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_used_per_km
# 0  toyota  White         150043      4   $4,000.00      3               7.5
# 1   honda    Red          87899      4   $5,000.00      5               4.5
# 2  toyota   Blue          32549      3   $7,000.00      6               2.3
# 3     bmw  Black          11179      5  $22,000.00      7               5.4
# 4  nissan  White         213095      4   $3,500.00      8               6.7
# 5  toyota  Green          99213      4   $4,500.00      9               7.8
# 6   honda   Blue          45698      4   $7,500.00      4               9.5
# 7   honda   Blue          54738      4   $7,000.00      5               4.4
# 8  toyota  White          60000      4   $6,250.00      6               6.7
# 9  nissan  White          31600      4   $9,700.00      2               8.9

# %%
car_sales["Total fuel used (KM)"] = car_sales["Odometer (KM)"] /100 * car_sales["fuel_used_per_km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_used_per_km  \
# 0  toyota  White         150043      4   $4,000.00      3               7.5
# 1   honda    Red          87899      4   $5,000.00      5               4.5
# 2  toyota   Blue          32549      3   $7,000.00      6               2.3
# 3     bmw  Black          11179      5  $22,000.00      7               5.4
# 4  nissan  White         213095      4   $3,500.00      8               6.7
# 5  toyota  Green          99213      4   $4,500.00      9               7.8
# 6   honda   Blue          45698      4   $7,500.00      4               9.5
# 7   honda   Blue          54738      4   $7,000.00      5               4.4
# 8  toyota  White          60000      4   $6,250.00      6               6.7
# 9  nissan  White          31600      4   $9,700.00      2               8.9
#
#    Total fuel used (KM)
# 0             11253.225
# 1              3955.455
# 2               748.627
# 3               603.666
# ...

# %%
car_sales['fuel_used_per_km'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Total fuel used (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Total fuel used (KM)'].hist()
# Out:
# <AxesSubplot:>
